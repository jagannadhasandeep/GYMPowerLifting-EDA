# %%
#Libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#Dataset

data = pd.read_csv(r"C:\Users\sandy\sandeep\datasets\GYM.csv")

# %%
data
# Out:
#          Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 0     Jessica Wilson   46        59 kg  Bench Press                 269
# 1           John Doe   60        83 kg  Bench Press                 179
# 2        Emily Davis   41       105 kg  Bench Press                 235
# 3        Emily Davis   33        66 kg        Squat                 359
# 4       Laura Taylor   56        74 kg     Deadlift                 221
# ...              ...  ...          ...          ...                 ...
# 2995        John Doe   46        74 kg  Bench Press                 246
# 2996      Daniel Lee   39         Open     Deadlift                 244
# 2997    Sarah Thomas   62         Open        Squat                 148
# 2998     Chris Brown   32        93 kg  Bench Press                 333
# 2999      Daniel Lee   22        83 kg     Deadlift                 280
#
# [3000 rows x 5 columns]

# %%
data.head(50)
# Out:
#          Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 0     Jessica Wilson   46        59 kg  Bench Press                 269
# 1           John Doe   60        83 kg  Bench Press                 179
# 2        Emily Davis   41       105 kg  Bench Press                 235
# 3        Emily Davis   33        66 kg        Squat                 359
# 4       Laura Taylor   56        74 kg     Deadlift                 221
# 5       Sarah Thomas   56        74 kg        Squat                 264
# 6        Emily Davis   40        83 kg     Deadlift                 132
# 7     Jessica Wilson   25       120 kg  Bench Press                 178
# 8    Michael Johnson   55        93 kg        Squat                 265
# 9        Chris Brown   20        66 kg  Bench Press                 239
# 10      Laura Taylor   31        52 kg     Deadlift                 328
# 11        Daniel Lee   38        52 kg     Deadlift                 347
# ...

# %%
data.tail()
# Out:
#        Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 2995      John Doe   46        74 kg  Bench Press                 246
# 2996    Daniel Lee   39         Open     Deadlift                 244
# 2997  Sarah Thomas   62         Open        Squat                 148
# 2998   Chris Brown   32        93 kg  Bench Press                 333
# 2999    Daniel Lee   22        83 kg     Deadlift                 280

# %%
data.isnull()
# Out:
#       Lifter Name    Age  Weight Class  Lift Type  Amount Lifted (kg)
# 0           False  False         False      False               False
# 1           False  False         False      False               False
# 2           False  False         False      False               False
# 3           False  False         False      False               False
# 4           False  False         False      False               False
# ...           ...    ...           ...        ...                 ...
# 2995        False  False         False      False               False
# 2996        False  False         False      False               False
# 2997        False  False         False      False               False
# 2998        False  False         False      False               False
# 2999        False  False         False      False               False
#
# [3000 rows x 5 columns]

# %%
data.isnull().head(21)
# Out:
#     Lifter Name    Age  Weight Class  Lift Type  Amount Lifted (kg)
# 0         False  False         False      False               False
# 1         False  False         False      False               False
# 2         False  False         False      False               False
# 3         False  False         False      False               False
# 4         False  False         False      False               False
# 5         False  False         False      False               False
# 6         False  False         False      False               False
# 7         False  False         False      False               False
# 8         False  False         False      False               False
# 9         False  False         False      False               False
# 10        False  False         False      False               False
# 11        False  False         False      False               False
# 12        False  False         False      False               False
# ...

# %%
data.isnull().sum()
# Out:
# Lifter Name           0
# Age                   0
# Weight Class          0
# Lift Type             0
# Amount Lifted (kg)    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Lifter Name         3000 non-null   object
#  1   Age                 3000 non-null   int64
#  2   Weight Class        3000 non-null   object
#  3   Lift Type           3000 non-null   object
#  4   Amount Lifted (kg)  3000 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 117.3+ KB

# %%
data[data.index == 40]
# Out:
#      Lifter Name  Age Weight Class Lift Type  Amount Lifted (kg)
# 40  Sarah Thomas   23        83 kg     Squat                 275

# %%
#Isolating tweo or more rows using []
#Similarly, two or more rows can be returned using the .isin() method instead of a == operator.
data[data.index.isin(range(20,41))]
# Out:
#          Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 20    Jessica Wilson   62        66 kg        Squat                 107
# 21      Sarah Thomas   55        52 kg        Squat                 169
# 22  Matthew Anderson   52        66 kg  Bench Press                 275
# 23      Sarah Thomas   56        59 kg        Squat                 391
# 24       Chris Brown   39        52 kg     Deadlift                 210
# 25       Emily Davis   46       105 kg        Squat                 271
# 26          John Doe   52        74 kg     Deadlift                 136
# 27       Emily Davis   19        74 kg  Bench Press                 254
# 28    Jessica Wilson   63       105 kg  Bench Press                 105
# 29          John Doe   64       105 kg        Squat                 263
# 30   Michael Johnson   35        93 kg  Bench Press                 217
# 31       Emily Davis   52        74 kg  Bench Press                 310
# ...

# %%
data.iloc[10:50]
# Out:
#          Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 10      Laura Taylor   31        52 kg     Deadlift                 328
# 11        Daniel Lee   38        52 kg     Deadlift                 347
# 12  Matthew Anderson   64        74 kg  Bench Press                 398
# 13  Matthew Anderson   47       120 kg  Bench Press                 396
# 14        Jane Smith   50        74 kg  Bench Press                 111
# 15        Daniel Lee   37        59 kg     Deadlift                 133
# 16      Laura Taylor   62        74 kg     Deadlift                 396
# 17      Laura Taylor   62       105 kg     Deadlift                 273
# 18  Matthew Anderson   40       120 kg  Bench Press                 120
# 19        Jane Smith   40        83 kg     Deadlift                 245
# 20    Jessica Wilson   62        66 kg        Squat                 107
# 21      Sarah Thomas   55        52 kg        Squat                 169
# ...

# %%
data.columns
# Out:
# Index(['Lifter Name', 'Age', 'Weight Class', 'Lift Type',
#        'Amount Lifted (kg)'],
#       dtype='object')

# %%
data['Amount Lifted (kg)'].value_counts()
# Out:
# Amount Lifted (kg)
# 276    22
# 138    18
# 223    17
# 244    17
# 100    17
#        ..
# 301     4
# 382     3
# 160     3
# 108     3
# 105     3
# Name: count, Length: 300, dtype: int64

# %%
data['Lift Type'].value_counts()
# Out:
# Lift Type
# Deadlift       1025
# Bench Press    1011
# Squat           964
# Name: count, dtype: int64

# %%
data.nlargest(5, 'Amount Lifted (kg)')
# Out:
#           Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 585        Jane Smith   58        74 kg     Deadlift                 399
# 1207  Michael Johnson   51        93 kg  Bench Press                 399
# 1409       Daniel Lee   24        66 kg        Squat                 399
# 1727     Sarah Thomas   51        59 kg     Deadlift                 399
# 2105  Michael Johnson   57        93 kg        Squat                 399

# %%
data.nsmallest(10, 'Amount Lifted (kg)')
# Out:
#           Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 339        Daniel Lee   29        59 kg  Bench Press                 100
# 369        Jane Smith   52         Open  Bench Press                 100
# 538   Michael Johnson   47         Open        Squat                 100
# 576       Emily Davis   56       105 kg  Bench Press                 100
# 871        Jane Smith   55        66 kg        Squat                 100
# 890        Daniel Lee   40        52 kg     Deadlift                 100
# 936   Michael Johnson   39        83 kg     Deadlift                 100
# 999      Laura Taylor   27        93 kg     Deadlift                 100
# 1100         John Doe   37        83 kg     Deadlift                 100
# 1215       Jane Smith   19        83 kg     Deadlift                 100

# %%
data.shape[0]
# Out:
# 3000

# %%
data.shape[1]
# Out:
# 5

# %%
data.describe()
# Out:
#                Age  Amount Lifted (kg)
# count  3000.000000         3000.000000
# mean     41.064000          250.332667
# std      13.682628           86.281208
# min      18.000000          100.000000
# 25%      29.000000          176.750000
# 50%      41.000000          250.000000
# 75%      53.000000          325.250000
# max      64.000000          399.000000

# %%
plt.figsize = (20,20)
sns.histplot(data ,y="Amount Lifted (kg)",x="Age")
# Out:
# <Axes: xlabel='Age', ylabel='Amount Lifted (kg)'>

# %%
plt.figsize = (100,100)
sns.displot(data, y="Age",x="Lift Type")

# %%
plt.figsize = (10,20)
sns.relplot(data ,y="Weight Class", x="Amount Lifted (kg)")

# %%
plt.figsize = (100,100)
sns.barplot(data , x="Lifter Name", y="Age")
# Out:
# <Axes: xlabel='Lifter Name', ylabel='Age'>

# %%
sns.lmplot(y="Amount Lifted (kg)", x="Age", data=data)

# %%
plt.figsize = (100,100)
sns.catplot(data=data, x="Weight Class", y="Lift Type")

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(10, 10))
sns.histplot(data=data, x='Lift Type', hue='Amount Lifted (kg)', bins=10, kde=True, multiple="stack")

# Add labels
plt.xlabel('Lift Type')
plt.ylabel('Amount Lifted (kg)')

# Show the plot
plt.show()
# Out:
# C:\Users\sandy\anaconda3\Lib\site-packages\seaborn\distributions.py:267: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   baselines[cols] = curves[cols].shift(1, axis=1).fillna(0)
# C:\Users\sandy\anaconda3\Lib\site-packages\seaborn\distributions.py:267: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   baselines[cols] = curves[cols].shift(1, axis=1).fillna(0)

# %%
status_counts = data['Weight Class'].value_counts()
plt.figure(figsize=(10, 10))
plt.pie(status_counts, labels=status_counts.index, autopct='%1.1f%%', startangle=140)
plt.show()

# %%
sns.boxplot(x="Age", y="Weight Class", data=data)

plt.xlabel("Age")
plt.ylabel("Weight Class")
plt.show()

# %%
sns.violinplot(x="Weight Class", y="Lift Type", data=data)

plt.xlabel("Weight Class")
plt.ylabel("Lift Type")
plt.show()

# %%
corr_matrix = data.select_dtypes(include=['number']).corr()

# Create a heatmap
plt.figure(figsize=(10, 10))
sns.heatmap(corr_matrix, annot=True, cmap=sns.cubehelix_palette(as_cmap=True), linewidths=0.5)

plt.show()

# %%
sns.pairplot(data.select_dtypes(include=['number']))

plt.show()
